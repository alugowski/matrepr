# %% [markdown]
# # MatRepr PyTorch
#
# Neatly format `torch.tensor`.
#
# 1D dense and sparse tensors are formatted as row vectors.
#
# 2D dense and sparse tensors are formatted as matrices.
#
# 3D+ sparse tensors are formatted as a list of index/value tuples, including hybrid tensors. Dense 3D+ tensors rendered with native PyTorch formatter.
#
# There are many possible `torch.tensor` layouts, not all combinations are supported by MatRepr. Those will fall back to the native `__str__()` formatter. For example: scalars, 3D+ dense tensors, CSR/CSC with batch dimensions, etc.

# %%
import torch

import numpy
numpy.random.seed(1234)

# so matrepr can be imported from the source tree.
import sys
sys.path.insert(0, '..')

from matrepr import mdisplay, mprint

# filter beta state warning
import warnings
warnings.filterwarnings("ignore", message="Sparse CSR tensor support is in beta state")

# %%
scalar = torch.tensor(5)

dense1D = torch.rand(5000)

rand2D = torch.rand(128, 64)
rand2D[rand2D < 0.6] = 0
rand2D_CSR = rand2D.to_sparse_csr()

small3D = torch.tensor([[[1., 0], [2., 3.]], [[4., 0], [5., 6.]]])
coo3D = small3D.to_sparse_coo()
coo3D_hybrid = small3D.to_sparse(2)

# %%
dense1D
# Out:
# tensor([0.9123, 0.2138, 0.1577,  ..., 0.2302, 0.3208, 0.6786])

# %%
rand2D_CSR
# Out:
# tensor(crow_indices=tensor([   0,   25,   53,   77,  101,  127,  149,  172,
#                              203,  229,  258,  280,  307,  328,  354,  385,
#                              412,  450,  474,  493,  524,  551,  581,  608,
#                              630,  659,  690,  719,  748,  775,  795,  817,
#                              844,  862,  884,  910,  934,  962,  996, 1024,
#                             1048, 1081, 1105, 1134, 1161, 1192, 1230, 1253,
#                             1277, 1298, 1332, 1357, 1392, 1423, 1445, 1476,
#                             1511, 1533, 1552, 1576, 1605, 1629, 1652, 1676,
#                             1708, 1730, 1758, 1783, 1804, 1821, 1847, 1878,
#                             1903, 1932, 1959, 1985, 2018, 2039, 2063, 2086,
#                             2113, 2134, 2157, 2173, 2199, 2218, 2241, 2269,
#                             2300, 2321, 2342, 2368, 2389, 2418, 2436, 2464,
#                             2493, 2519, 2542, 2568, 2588, 2612, 2642, 2668,
#                             2692, 2717, 2739, 2759, 2791, 2813, 2837, 2858,
#                             2877, 2902, 2932, 2955, 2981, 3003, 3025, 3051,
#                             3078, 3103, 3135, 3160, 3184, 3212, 3236, 3263,
#                             3286]),
#        col_indices=tensor([ 1,  3,  5,  ..., 54, 55, 60]),
#        values=tensor([0.6698, 0.6196, 0.7489,  ..., 0.6112, 0.7558, 0.6966]),
#        size=(128, 64), nnz=3286, layout=torch.sparse_csr)

# %%
coo3D
# Out:
# tensor(indices=tensor([[0, 0, 0, 1, 1, 1],
#                        [0, 1, 1, 0, 1, 1],
#                        [0, 0, 1, 0, 0, 1]]),
#        values=tensor([1., 2., 3., 4., 5., 6.]),
#        size=(2, 2, 2), nnz=6, layout=torch.sparse_coo)

# %%
coo3D_hybrid
# Out:
# tensor(indices=tensor([[0, 0, 1, 1],
#                        [0, 1, 0, 1]]),
#        values=tensor([[1., 0.],
#                       [2., 3.],
#                       [4., 0.],
#                       [5., 6.]]),
#        size=(2, 2, 2), nnz=4, layout=torch.sparse_coo)

# %%
scalar
# Out:
# tensor(5)

# %% [markdown]
# ## MatRepr default
#
# Load the MatRepr Jupyter extension with `%load_ext matrepr` to render tensors with MatRepr by default.
#
# A single-use alternative is to use `matrepr.mdisplay()`. For console use `matrepr.mprint()`.

# %%
# %load_ext matrepr

# %%
dense1D
# Out:
# tensor([0.9123, 0.2138, 0.1577,  ..., 0.2302, 0.3208, 0.6786])

# %%
rand2D_CSR
# Out:
# tensor(crow_indices=tensor([   0,   25,   53,   77,  101,  127,  149,  172,
#                              203,  229,  258,  280,  307,  328,  354,  385,
#                              412,  450,  474,  493,  524,  551,  581,  608,
#                              630,  659,  690,  719,  748,  775,  795,  817,
#                              844,  862,  884,  910,  934,  962,  996, 1024,
#                             1048, 1081, 1105, 1134, 1161, 1192, 1230, 1253,
#                             1277, 1298, 1332, 1357, 1392, 1423, 1445, 1476,
#                             1511, 1533, 1552, 1576, 1605, 1629, 1652, 1676,
#                             1708, 1730, 1758, 1783, 1804, 1821, 1847, 1878,
#                             1903, 1932, 1959, 1985, 2018, 2039, 2063, 2086,
#                             2113, 2134, 2157, 2173, 2199, 2218, 2241, 2269,
#                             2300, 2321, 2342, 2368, 2389, 2418, 2436, 2464,
#                             2493, 2519, 2542, 2568, 2588, 2612, 2642, 2668,
#                             2692, 2717, 2739, 2759, 2791, 2813, 2837, 2858,
#                             2877, 2902, 2932, 2955, 2981, 3003, 3025, 3051,
#                             3078, 3103, 3135, 3160, 3184, 3212, 3236, 3263,
#                             3286]),
#        col_indices=tensor([ 1,  3,  5,  ..., 54, 55, 60]),
#        values=tensor([0.6698, 0.6196, 0.7489,  ..., 0.6112, 0.7558, 0.6966]),
#        size=(128, 64), nnz=3286, layout=torch.sparse_csr)

# %%
coo3D
# Out:
# tensor(indices=tensor([[0, 0, 0, 1, 1, 1],
#                        [0, 1, 1, 0, 1, 1],
#                        [0, 0, 1, 0, 0, 1]]),
#        values=tensor([1., 2., 3., 4., 5., 6.]),
#        size=(2, 2, 2), nnz=6, layout=torch.sparse_coo)

# %%
coo3D_hybrid
# Out:
# tensor(indices=tensor([[0, 0, 1, 1],
#                        [0, 1, 0, 1]]),
#        values=tensor([[1., 0.],
#                       [2., 3.],
#                       [4., 0.],
#                       [5., 6.]]),
#        size=(2, 2, 2), nnz=4, layout=torch.sparse_coo)

# %%
scalar
# Out:
# tensor(5)

# %% [markdown]
# # Labels
#
# Specify title, row and/or column labels to help the reader quickly understand what they are looking at.

# %%
tensor = torch.rand(64, 32)
tensor[tensor < 0.3] = 0
tensor = tensor.to_sparse()

obs_labels = [f"observation {i}" for i in range(tensor.shape[0])]  # list of labels
feature_labels = {i: f"feature {i+1}" for i in range(tensor.shape[1])}  # map index to label works too

# %%
mdisplay(tensor, row_labels=obs_labels, col_labels=feature_labels, title="Random Dataset", max_cols=11)
# Out:
# <div>
# <style scoped>
#     table.matreprmatrix caption {
#         white-space: pre;
#         text-align: center;
#     }
#     table.matreprmatrix  {
#         border-collapse: collapse;
#     }
#     table.matreprmatrix > thead  {
#         border: 0px;
#     }
#     table.matreprmatrix > tbody tr th {
#         font-size: smaller;
#         vertical-align: middle;
#         text-align: right;
#     }
#     table.matreprmatrix > thead tr th {
#         font-size: smaller;
#         vertical-align: middle;
#         text-align: center;
#     }
#     table.matreprmatrix > tbody tr td {
#         vertical-align: middle;
#         text-align: center;
#         position: relative;
#     }
#     table.matreprmatrix > tbody tr td:first-of-type {
#         border-left: solid 2px;
#     }
#     table.matreprmatrix > tbody tr td:last-of-type {
#         border-right: solid 2px;
#     }
#     table.matreprmatrix > tbody tr td:empty::before {
#         content: "\00a0\00a0\00a0";
#         visibility: hidden;
#     }
#     table.matreprmatrix > tbody tr td:empty::after {
#         content: "\00a0\00a0\00a0";
#         visibility: hidden;
#     }
#     table.matreprmatrix > tbody > tr:first-child > td:first-of-type::before {
#         content: "";
#         width: 4px;
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         visibility: visible;
#         left: 0;
#         right: auto;
#         border-top: solid 2px;
#     }
#     table.matreprmatrix > tbody > tr:last-child > td:first-of-type::before {
#         content: "";
#         width: 4px;
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         visibility: visible;
#         left: 0;
#         right: auto;
#         border-bottom: solid 2px;
#     }
#     table.matreprmatrix > tbody > tr:first-child > td:last-of-type::after {
#         content: "";
#         width: 4px;
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         visibility: visible;
#         left: auto;
#         right: 0;
#         border-top: solid 2px;
#     }
#     table.matreprmatrix > tbody > tr:last-child > td:last-of-type::after {
#         content: "";
#         width: 4px;
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         visibility: visible;
#         left: auto;
#         right: 0;
#         border-bottom: solid 2px;
#     }
#     table.matreprtensor caption {
#         white-space: pre;
#         text-align: center;
#     }
#     table.matreprtensor > thead  {
#         border: 0px;
#     }
#     table.matreprtensor > tbody tr th {
#         font-size: smaller;
#         vertical-align: middle;
#         text-align: right;
#     }
#     table.matreprtensor > thead tr th {
#         font-size: smaller;
#         vertical-align: middle;
#         text-align: center;
#     }
#     table.matreprtensor > tbody tr td {
#         vertical-align: middle;
#         text-align: center;
#         position: relative;
#     }
#     table.matreprtensor > tbody tr th:last-of-type {
#         border-right: solid 2px;
#     }
# </style>
# <table class="matreprmatrix">
# <caption>Random Dataset</caption>
#     <thead>
#     <tr>
#         <th></th>
#         <th style="text-align: center;">feature 1</th>
#         <th style="text-align: center;">feature 2</th>
#         <th style="text-align: center;">feature 3</th>
#         <th style="text-align: center;">feature 4</th>
#         <th style="text-align: center;">feature 5</th>
#         <th style="text-align: center;"></th>
#         <th style="text-align: center;">feature 28</th>
#         <th style="text-align: center;">feature 29</th>
#         <th style="text-align: center;">feature 30</th>
#         <th style="text-align: center;">feature 31</th>
#         <th style="text-align: center;">feature 32</th>
#     </tr>
#     </thead>
#     <tbody>
#     <tr>
#         <th>observation 0</th>
#         <td style="text-align: center;">0.3472</td>
#         <td style="text-align: center;">0.4712</td>
#         <td style="text-align: center;">0.4631</td>
#         <td style="text-align: center;">0.4087</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.9262</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.433</td>
#         <td style="text-align: center;">0.8568</td>
#     </tr>
#     <tr>
#         <th>observation 1</th>
#         <td style="text-align: center;">0.7922</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.7093</td>
#         <td style="text-align: center;">0.4448</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;">0.9246</td>
#         <td style="text-align: center;">0.9083</td>
#         <td style="text-align: center;">0.8335</td>
#         <td style="text-align: center;">0.815</td>
#         <td style="text-align: center;">0.6405</td>
#     </tr>
#     <tr>
#         <th>observation 2</th>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.5853</td>
#         <td style="text-align: center;">0.9673</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.5242</td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;">0.952</td>
#         <td style="text-align: center;">0.8521</td>
#         <td style="text-align: center;">0.8307</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.3719</td>
#     </tr>
#     <tr>
#         <th>observation 3</th>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.9561</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.9454</td>
#         <td style="text-align: center;">0.3552</td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.6674</td>
#         <td style="text-align: center;">0.9862</td>
#         <td style="text-align: center;">0.5422</td>
#         <td style="text-align: center;">0.3391</td>
#     </tr>
#     <tr>
#         <th>observation 4</th>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.9543</td>
#         <td style="text-align: center;">0.6766</td>
#         <td style="text-align: center;">0.5506</td>
#         <td style="text-align: center;">0.5841</td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;">0.5843</td>
#         <td style="text-align: center;">0.8764</td>
#         <td style="text-align: center;">0.6554</td>
#         <td style="text-align: center;">0.8808</td>
#         <td style="text-align: center;"></td>
#     </tr>
#     <tr>
#         <th></th>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&dtdot;</td>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&vellip;</td>
#     </tr>
#     <tr>
#         <th>observation 59</th>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.5496</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.7716</td>
#         <td style="text-align: center;">0.9963</td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;">0.8506</td>
#         <td style="text-align: center;">0.7186</td>
#         <td style="text-align: center;">0.6416</td>
#         <td style="text-align: center;">0.8713</td>
#         <td style="text-align: center;">0.525</td>
#     </tr>
#     <tr>
#         <th>observation 60</th>
#         <td style="text-align: center;">0.9826</td>
#         <td st

# %% [markdown]
# ## LaTeX

# %%
mdisplay(rand2D_CSR, "latex")
# Out:
# $\begin{bmatrix}
#      & 0.6698 &  & 0.6196 &  & 0.7489 & 0.8952 & \dots &  & 0.6021 & 0.6449 & 0.8717 &  &  & 0.9785 \\
#      & 0.9144 & 0.7465 &  & 0.8148 &  & 0.9172 & \dots &  &  &  &  & 0.8863 &  &  \\
#      &  &  &  &  & 0.8973 &  & \dots &  &  &  &  &  &  & 0.9478 \\
#      & 0.9928 &  &  &  &  &  & \dots & 0.9838 & 0.6982 & 0.7416 &  &  &  & 0.9504 \\
#     0.9618 & 0.6501 & 0.9263 & 0.844 &  &  & 0.8712 & \dots &  &  & 0.8267 &  &  &  &  \\
#     \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \ddots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots \\
#     0.6765 & 0.9631 &  & 0.9067 &  &  & 0.767 & \dots & 0.7601 &  & 0.97 &  & 0.9297 &  &  \\
#      & 0.8878 &  &  &  & 0.8579 & 0.7423 & \dots &  & 0.6537 & 0.9821 & 0.6675 &  &  &  \\
#      &  &  &  &  &  &  & \dots & 0.967 & 0.7392 & 0.8582 &  & 0.6025 &  &  \\
#      &  &  &  &  & 0.6808 &  & \dots &  &  &  &  &  &  &  \\
#      &  &  &  & 0.8987 & 0.9682 &  & \dots &  &  &  & 0.6966 &  &  &
# \end{bmatrix}$

# %% [markdown]
# ## String

# %%
mprint(rand2D_CSR)
# Out:
# <128×64, 3286 'torch.float32' elements, torch.sparse_csr>
#         0       1       2       3            60      61     62     63
#     ┌                                                                   ┐
#   0 │         0.6698                  ...  0.8717                0.9785 │
#   1 │         0.9144  0.7465          ...          0.8863               │
#   2 │                         0.979   ...                        0.9478 │
#   3 │         0.9928          0.744   ...                        0.9504 │
#   4 │ 0.9618  0.6501  0.9263          ...                               │
#     │   :       :       :       :     ...    :       :      :      :    │
# 123 │ 0.6765  0.9631                  ...          0.9297               │
# 124 │         0.8878                  ...  0.6675                       │
# 125 │                         0.9118  ...          0.6025               │
# 126 │                                 ...                               │
# 127 │                                 ...  0.6966                       │
#     └                                                                   ┘

# %% [markdown]
# ## More compact size

# %%
import matrepr
matrepr.params.max_rows = 10
matrepr.params.max_cols = 7
matrepr.params.num_after_dots = 0

# %%
rand2D_CSR
# Out:
# tensor(crow_indices=tensor([   0,   25,   53,   77,  101,  127,  149,  172,
#                              203,  229,  258,  280,  307,  328,  354,  385,
#                              412,  450,  474,  493,  524,  551,  581,  608,
#                              630,  659,  690,  719,  748,  775,  795,  817,
#                              844,  862,  884,  910,  934,  962,  996, 1024,
#                             1048, 1081, 1105, 1134, 1161, 1192, 1230, 1253,
#                             1277, 1298, 1332, 1357, 1392, 1423, 1445, 1476,
#                             1511, 1533, 1552, 1576, 1605, 1629, 1652, 1676,
#                             1708, 1730, 1758, 1783, 1804, 1821, 1847, 1878,
#                             1903, 1932, 1959, 1985, 2018, 2039, 2063, 2086,
#                             2113, 2134, 2157, 2173, 2199, 2218, 2241, 2269,
#                             2300, 2321, 2342, 2368, 2389, 2418, 2436, 2464,
#                             2493, 2519, 2542, 2568, 2588, 2612, 2642, 2668,
#                             2692, 2717, 2739, 2759, 2791, 2813, 2837, 2858,
#                             2877, 2902, 2932, 2955, 2981, 3003, 3025, 3051,
#                             3078, 3103, 3135, 3160, 3184, 3212, 3236, 3263,
#                             3286]),
#        col_indices=tensor([ 1,  3,  5,  ..., 54, 55, 60]),
#        values=tensor([0.6698, 0.6196, 0.7489,  ..., 0.6112, 0.7558, 0.6966]),
#        size=(128, 64), nnz=3286, layout=torch.sparse_csr)
