# %% [markdown]
# # MatRepr PyTorch
#
# Neatly format `torch.tensor`.
#
# 1D dense and sparse tensors are formatted as row vectors.
#
# 2D dense and sparse tensors are formatted as matrices.
#
# 3D+ sparse tensors are formatted as a list of index/value tuples, including hybrid tensors. Dense 3D+ tensors rendered with native PyTorch formatter.
#
# There are many possible `torch.tensor` layouts, not all combinations are supported by MatRepr. Those will fall back to the native `__str__()` formatter. For example: scalars, 3D+ dense tensors, CSR/CSC with batch dimensions, etc.

# %%
import torch

import numpy
numpy.random.seed(1234)

# so matrepr can be imported from the source tree.
import sys
sys.path.insert(0, '..')

from matrepr import mdisplay, mprint

# filter beta state warning
import warnings
warnings.filterwarnings("ignore", message="Sparse CSR tensor support is in beta state")

# %%
scalar = torch.tensor(5)

dense1D = torch.rand(5000)

rand2D = torch.rand(128, 64)
rand2D[rand2D < 0.6] = 0
rand2D_CSR = rand2D.to_sparse_csr()

small3D = torch.tensor([[[1., 0], [2., 3.]], [[4., 0], [5., 6.]]])
coo3D = small3D.to_sparse_coo()
coo3D_hybrid = small3D.to_sparse(2)

# %%
dense1D
# Out:
# tensor([0.2768, 0.5723, 0.8491,  ..., 0.8538, 0.9845, 0.3700])

# %%
rand2D_CSR
# Out:
# tensor(crow_indices=tensor([   0,   28,   54,   81,  106,  127,  149,  177,
#                              205,  233,  260,  284,  309,  336,  360,  390,
#                              411,  437,  462,  490,  515,  531,  557,  581,
#                              606,  631,  654,  677,  703,  727,  758,  781,
#                              812,  836,  864,  886,  913,  938,  967,  989,
#                             1017, 1035, 1069, 1086, 1108, 1140, 1165, 1185,
#                             1217, 1247, 1270, 1294, 1319, 1348, 1374, 1408,
#                             1431, 1460, 1483, 1510, 1533, 1561, 1586, 1607,
#                             1630, 1653, 1677, 1713, 1737, 1768, 1791, 1818,
#                             1848, 1873, 1897, 1923, 1947, 1970, 1987, 2013,
#                             2040, 2066, 2098, 2125, 2149, 2173, 2201, 2228,
#                             2251, 2279, 2302, 2331, 2356, 2381, 2409, 2431,
#                             2460, 2487, 2509, 2535, 2559, 2575, 2598, 2616,
#                             2640, 2665, 2697, 2725, 2752, 2779, 2806, 2834,
#                             2861, 2890, 2908, 2939, 2971, 3003, 3028, 3050,
#                             3072, 3102, 3133, 3161, 3187, 3211, 3237, 3268,
#                             3294]),
#        col_indices=tensor([ 1,  3,  4,  ..., 59, 60, 62]),
#        values=tensor([0.9397, 0.9540, 0.9056,  ..., 0.9907, 0.8187, 0.7503]),
#        size=(128, 64), nnz=3294, layout=torch.sparse_csr)

# %%
coo3D
# Out:
# tensor(indices=tensor([[0, 0, 0, 1, 1, 1],
#                        [0, 1, 1, 0, 1, 1],
#                        [0, 0, 1, 0, 0, 1]]),
#        values=tensor([1., 2., 3., 4., 5., 6.]),
#        size=(2, 2, 2), nnz=6, layout=torch.sparse_coo)

# %%
coo3D_hybrid
# Out:
# tensor(indices=tensor([[0, 0, 1, 1],
#                        [0, 1, 0, 1]]),
#        values=tensor([[1., 0.],
#                       [2., 3.],
#                       [4., 0.],
#                       [5., 6.]]),
#        size=(2, 2, 2), nnz=4, layout=torch.sparse_coo)

# %%
scalar
# Out:
# tensor(5)

# %% [markdown]
# ## MatRepr default
#
# Load the MatRepr Jupyter extension with `%load_ext matrepr` to render tensors with MatRepr by default.
#
# A single-use alternative is to use `matrepr.mdisplay()`. For console use `matrepr.mprint()`.

# %%
# %load_ext matrepr

# %%
dense1D
# Out:
# tensor([0.2768, 0.5723, 0.8491,  ..., 0.8538, 0.9845, 0.3700])

# %%
rand2D_CSR
# Out:
# tensor(crow_indices=tensor([   0,   28,   54,   81,  106,  127,  149,  177,
#                              205,  233,  260,  284,  309,  336,  360,  390,
#                              411,  437,  462,  490,  515,  531,  557,  581,
#                              606,  631,  654,  677,  703,  727,  758,  781,
#                              812,  836,  864,  886,  913,  938,  967,  989,
#                             1017, 1035, 1069, 1086, 1108, 1140, 1165, 1185,
#                             1217, 1247, 1270, 1294, 1319, 1348, 1374, 1408,
#                             1431, 1460, 1483, 1510, 1533, 1561, 1586, 1607,
#                             1630, 1653, 1677, 1713, 1737, 1768, 1791, 1818,
#                             1848, 1873, 1897, 1923, 1947, 1970, 1987, 2013,
#                             2040, 2066, 2098, 2125, 2149, 2173, 2201, 2228,
#                             2251, 2279, 2302, 2331, 2356, 2381, 2409, 2431,
#                             2460, 2487, 2509, 2535, 2559, 2575, 2598, 2616,
#                             2640, 2665, 2697, 2725, 2752, 2779, 2806, 2834,
#                             2861, 2890, 2908, 2939, 2971, 3003, 3028, 3050,
#                             3072, 3102, 3133, 3161, 3187, 3211, 3237, 3268,
#                             3294]),
#        col_indices=tensor([ 1,  3,  4,  ..., 59, 60, 62]),
#        values=tensor([0.9397, 0.9540, 0.9056,  ..., 0.9907, 0.8187, 0.7503]),
#        size=(128, 64), nnz=3294, layout=torch.sparse_csr)

# %%
coo3D
# Out:
# tensor(indices=tensor([[0, 0, 0, 1, 1, 1],
#                        [0, 1, 1, 0, 1, 1],
#                        [0, 0, 1, 0, 0, 1]]),
#        values=tensor([1., 2., 3., 4., 5., 6.]),
#        size=(2, 2, 2), nnz=6, layout=torch.sparse_coo)

# %%
coo3D_hybrid
# Out:
# tensor(indices=tensor([[0, 0, 1, 1],
#                        [0, 1, 0, 1]]),
#        values=tensor([[1., 0.],
#                       [2., 3.],
#                       [4., 0.],
#                       [5., 6.]]),
#        size=(2, 2, 2), nnz=4, layout=torch.sparse_coo)

# %%
scalar
# Out:
# tensor(5)

# %% [markdown]
# # Labels
#
# Specify title, row and/or column labels to help the reader quickly understand what they are looking at.

# %%
tensor = torch.rand(64, 32)
tensor[tensor < 0.3] = 0
tensor = tensor.to_sparse()

obs_labels = [f"observation {i}" for i in range(tensor.shape[0])]  # list of labels
feature_labels = {i: f"feature {i+1}" for i in range(tensor.shape[1])}  # map index to label works too

# %%
mdisplay(tensor, row_labels=obs_labels, col_labels=feature_labels, title="Random Dataset")
# Out:
# <div>
# <style scoped>
#     table.matreprmatrix caption {
#         white-space: pre;
#         text-align: center;
#     }
#     table.matreprmatrix  {
#         border-collapse: collapse;
#     }
#     table.matreprmatrix > thead  {
#         border: 0px;
#     }
#     table.matreprmatrix > tbody tr th {
#         font-size: smaller;
#         vertical-align: middle;
#         text-align: right;
#     }
#     table.matreprmatrix > thead tr th {
#         font-size: smaller;
#         vertical-align: middle;
#         text-align: center;
#     }
#     table.matreprmatrix > tbody tr td {
#         vertical-align: middle;
#         text-align: center;
#         position: relative;
#     }
#     table.matreprmatrix > tbody tr td:first-of-type {
#         border-left: solid 2px;
#     }
#     table.matreprmatrix > tbody tr td:last-of-type {
#         border-right: solid 2px;
#     }
#     table.matreprmatrix > tbody tr td:empty::before {
#         content: "\00a0\00a0\00a0";
#         visibility: hidden;
#     }
#     table.matreprmatrix > tbody tr td:empty::after {
#         content: "\00a0\00a0\00a0";
#         visibility: hidden;
#     }
#     table.matreprmatrix > tbody > tr:first-child > td:first-of-type::before {
#         content: "";
#         width: 4px;
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         visibility: visible;
#         left: 0;
#         right: auto;
#         border-top: solid 2px;
#     }
#     table.matreprmatrix > tbody > tr:last-child > td:first-of-type::before {
#         content: "";
#         width: 4px;
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         visibility: visible;
#         left: 0;
#         right: auto;
#         border-bottom: solid 2px;
#     }
#     table.matreprmatrix > tbody > tr:first-child > td:last-of-type::after {
#         content: "";
#         width: 4px;
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         visibility: visible;
#         left: auto;
#         right: 0;
#         border-top: solid 2px;
#     }
#     table.matreprmatrix > tbody > tr:last-child > td:last-of-type::after {
#         content: "";
#         width: 4px;
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         visibility: visible;
#         left: auto;
#         right: 0;
#         border-bottom: solid 2px;
#     }
#     table.matreprtensor caption {
#         white-space: pre;
#         text-align: center;
#     }
#     table.matreprtensor > thead  {
#         border: 0px;
#     }
#     table.matreprtensor > tbody tr th {
#         font-size: smaller;
#         vertical-align: middle;
#         text-align: right;
#     }
#     table.matreprtensor > thead tr th {
#         font-size: smaller;
#         vertical-align: middle;
#         text-align: center;
#     }
#     table.matreprtensor > tbody tr td {
#         vertical-align: middle;
#         text-align: center;
#         position: relative;
#     }
#     table.matreprtensor > tbody tr th:last-of-type {
#         border-right: solid 2px;
#     }
# </style>
# <table class="matreprmatrix">
# <caption>Random Dataset</caption>
#     <thead>
#     <tr>
#         <th></th>
#         <th style="text-align: center;">feature 1</th>
#         <th style="text-align: center;">feature 2</th>
#         <th style="text-align: center;">feature 3</th>
#         <th style="text-align: center;">feature 4</th>
#         <th style="text-align: center;">feature 5</th>
#         <th style="text-align: center;">feature 6</th>
#         <th style="text-align: center;">feature 7</th>
#         <th style="text-align: center;"></th>
#         <th style="text-align: center;">feature 26</th>
#         <th style="text-align: center;">feature 27</th>
#         <th style="text-align: center;">feature 28</th>
#         <th style="text-align: center;">feature 29</th>
#         <th style="text-align: center;">feature 30</th>
#         <th style="text-align: center;">feature 31</th>
#         <th style="text-align: center;">feature 32</th>
#     </tr>
#     </thead>
#     <tbody>
#     <tr>
#         <th>observation 0</th>
#         <td style="text-align: center;">0.5137</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.3973</td>
#         <td style="text-align: center;">0.7045</td>
#         <td style="text-align: center;">0.9316</td>
#         <td style="text-align: center;">0.575</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;">0.6902</td>
#         <td style="text-align: center;">0.412</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.4136</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.3237</td>
#         <td style="text-align: center;">0.5993</td>
#     </tr>
#     <tr>
#         <th>observation 1</th>
#         <td style="text-align: center;">0.7785</td>
#         <td style="text-align: center;">0.7041</td>
#         <td style="text-align: center;">0.4703</td>
#         <td style="text-align: center;">0.7012</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.9141</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;">0.851</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.576</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.7691</td>
#         <td style="text-align: center;">0.3749</td>
#         <td style="text-align: center;">0.6756</td>
#     </tr>
#     <tr>
#         <th>observation 2</th>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.8683</td>
#         <td style="text-align: center;">0.9074</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.5763</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.959</td>
#         <td style="text-align: center;">0.3161</td>
#         <td style="text-align: center;">0.5851</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.4827</td>
#         <td style="text-align: center;">0.8321</td>
#     </tr>
#     <tr>
#         <th>observation 3</th>
#         <td style="text-align: center;">0.382</td>
#         <td style="text-align: center;">0.6755</td>
#         <td style="text-align: center;">0.6054</td>
#         <td style="text-align: center;">0.3906</td>
#         <td style="text-align: center;">0.8615</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.5283</td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;">0.4886</td>
#         <td style="text-align: center;">0.9308</td>
#         <td style="text-align: center;">0.958</td>
#         <td style="text-align: center;">0.3775</td>
#         <td style="text-align: center;">0.4915</td>
#         <td style="text-align: center;">0.7524</td>
#         <td style="text-align: center;"></td>
#     </tr>
#     <tr>
#         <th>observation 4</th>
#         <td style="text-align: center;">0.8116</td>
#         <td style="text-align: center;">0.3232</td>
#         <td style="text-align: center;">0.6763</td>
#         <td style="text-align: center;">0.6721</td>
#         <td style="text-align: center;">0.5907</td>
#         <td style="text-align: center;">0.4377</td>
#         <td style="text-align: center;">0.8974</td>
#         <td style="text-align: center;">&ctdot;</td>
#         <td style="text-align: center;">0.3873</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.933</td>
#         <td style="text-align: center;"></td>
#         <td style="text-align: center;">0.5685</td>
#         <td style="text-align: center;">0.86</td>
#         <td style="text-align: center;">0.5499</td>
#     </tr>
#     <tr>
#         <th></th>
#         <td style="text-align: center;">&vellip;</td>
#         <td style="text-align: center;">&v

# %% [markdown]
# ## LaTeX

# %%
mdisplay(rand2D_CSR, "latex")
# Out:
# $\begin{bmatrix}
#      & 0.9397 &  & 0.954 & 0.9056 &  & 0.6673 & \dots &  &  &  &  &  &  &  \\
#      &  & 0.8201 &  & 0.8047 & 0.7012 & 0.7345 & \dots & 0.9761 &  & 0.8241 &  & 0.8905 & 0.6337 &  \\
#     0.9003 &  &  &  &  & 0.6883 & 0.7676 & \dots &  &  & 0.7584 &  &  & 0.9717 &  \\
#      & 0.6402 & 0.8154 &  & 0.9241 & 0.8602 &  & \dots & 0.9347 &  &  &  &  &  & 0.6915 \\
#     0.8187 &  & 0.8371 &  &  &  &  & \dots &  &  &  & 0.8406 &  &  &  \\
#     \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \ddots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots \\
#     0.7965 &  &  &  &  & 0.8006 & 0.625 & \dots & 0.7264 & 0.8956 & 0.6836 &  &  &  & 0.841 \\
#      &  &  &  & 0.8356 &  & 0.6928 & \dots &  &  &  &  &  & 0.8911 &  \\
#      & 0.6616 &  & 0.8032 &  &  &  & \dots &  &  &  & 0.6878 & 0.7845 &  &  \\
#     0.8261 & 0.691 &  & 0.8957 & 0.9291 & 0.7503 &  & \dots &  &  & 0.609 &  &  & 0.9249 &  \\
#     0.8496 & 0.7369 &  &  &  & 0.882 & 0.97 & \dots &  &  & 0.9907 & 0.8187 &  & 0.7503 &
# \end{bmatrix}$

# %% [markdown]
# ## String

# %%
mprint(rand2D_CSR)
# Out:
# <128×64, 3294 'torch.float32' elements, torch.sparse_csr>
#         0       1       2       3            60      61      62      63
#     ┌                                                                     ┐
#   0 │         0.9397          0.768   ...                                 │
#   1 │                 0.8201          ...          0.8905  0.6337         │
#   2 │ 0.9003                          ...                  0.9717         │
#   3 │         0.6402  0.8154  0.7216  ...                          0.6915 │
#   4 │ 0.8187          0.8371          ...  0.8406                         │
#     │   :       :       :       :     ...    :       :       :       :    │
# 123 │ 0.7965                          ...                          0.841  │
# 124 │                         0.7442  ...                  0.8911         │
# 125 │         0.6616          0.6181  ...  0.6878  0.7845                 │
# 126 │ 0.8261  0.691           0.964   ...                  0.9249         │
# 127 │ 0.8496  0.7369          0.9116  ...  0.8187          0.7503         │
#     └                                                                     ┘

# %% [markdown]
# ## More compact size

# %%
import matrepr
matrepr.params.max_rows = 10
matrepr.params.max_cols = 7
matrepr.params.num_after_dots = 0

# %%
rand2D_CSR
# Out:
# tensor(crow_indices=tensor([   0,   28,   54,   81,  106,  127,  149,  177,
#                              205,  233,  260,  284,  309,  336,  360,  390,
#                              411,  437,  462,  490,  515,  531,  557,  581,
#                              606,  631,  654,  677,  703,  727,  758,  781,
#                              812,  836,  864,  886,  913,  938,  967,  989,
#                             1017, 1035, 1069, 1086, 1108, 1140, 1165, 1185,
#                             1217, 1247, 1270, 1294, 1319, 1348, 1374, 1408,
#                             1431, 1460, 1483, 1510, 1533, 1561, 1586, 1607,
#                             1630, 1653, 1677, 1713, 1737, 1768, 1791, 1818,
#                             1848, 1873, 1897, 1923, 1947, 1970, 1987, 2013,
#                             2040, 2066, 2098, 2125, 2149, 2173, 2201, 2228,
#                             2251, 2279, 2302, 2331, 2356, 2381, 2409, 2431,
#                             2460, 2487, 2509, 2535, 2559, 2575, 2598, 2616,
#                             2640, 2665, 2697, 2725, 2752, 2779, 2806, 2834,
#                             2861, 2890, 2908, 2939, 2971, 3003, 3028, 3050,
#                             3072, 3102, 3133, 3161, 3187, 3211, 3237, 3268,
#                             3294]),
#        col_indices=tensor([ 1,  3,  4,  ..., 59, 60, 62]),
#        values=tensor([0.9397, 0.9540, 0.9056,  ..., 0.9907, 0.8187, 0.7503]),
#        size=(128, 64), nnz=3294, layout=torch.sparse_csr)
